# %%
import insightface
import matplotlib.pyplot as plt
import random
from decord import VideoReader,cpu
import cv2
import numpy as np

# %%
filename = '/group_homes/public_cluster/home/share/LipReadingGroup/data/LRS2/pretrain/5945344987164963843/00016.mp4'
with open(filename, 'rb') as f:
    vr = VideoReader(f, ctx=cpu())
video = [vr[i].asnumpy() for i in range(len(vr))]
video = np.stack(video)

# %%
plt.imshow(video[0])
